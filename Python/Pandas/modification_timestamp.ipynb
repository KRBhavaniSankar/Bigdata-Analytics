# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv(path)
df.shape
# Out:
# (42822, 4)

# %%
df = df[['imei','AdID','timestamp']]
df.head(5)
# Out:
#                        imei                                  AdID  \
# 0  04G0LT445QLQT5NTP40L5TPG  28075d03-b93c-4fb6-830e-b56521c50248
# 1  04G5NNOJ5QONQ5JTP4LG5TPQ  10e21cbe-9284-423b-8338-a38cbe23d459
# 2  04GG4TT55JTL05QTP4LJ5TPG  fac98d45-50b9-43c3-beb2-990e6348f5dd
# 3  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 4  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
#
#                   timestamp
# 0  2018-06-01T16:57:55.000Z
# 1  2018-12-27T11:59:50.000Z
# 2  2018-06-17T19:26:50.000Z
# 3  2018-10-09T16:26:55.000Z
# 4  2018-11-16T12:31:14.000Z

# %%
from datetime import datetime, timedelta
df['jst_time'] = pd.DatetimeIndex(df['timestamp']) - timedelta(hours=0)
df['utc_time'] = pd.DatetimeIndex(df['timestamp']) - timedelta(hours=9)
df['hour_before']= pd.DatetimeIndex(df['utc_time']) - timedelta(hours=1)
df = df[['imei','AdID','jst_time','utc_time','hour_before']]
df.head(5)
# Out:
#                        imei                                  AdID  \
# 0  04G0LT445QLQT5NTP40L5TPG  28075d03-b93c-4fb6-830e-b56521c50248
# 1  04G5NNOJ5QONQ5JTP4LG5TPQ  10e21cbe-9284-423b-8338-a38cbe23d459
# 2  04GG4TT55JTL05QTP4LJ5TPG  fac98d45-50b9-43c3-beb2-990e6348f5dd
# 3  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 4  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
#
#              jst_time            utc_time         hour_before
# 0 2018-06-01 16:57:55 2018-06-01 07:57:55 2018-06-01 06:57:55
# 1 2018-12-27 11:59:50 2018-12-27 02:59:50 2018-12-27 01:59:50
# 2 2018-06-17 19:26:50 2018-06-17 10:26:50 2018-06-17 09:26:50
# 3 2018-10-09 16:26:55 2018-10-09 07:26:55 2018-10-09 06:26:55
# 4 2018-11-16 12:31:14 2018-11-16 03:31:14 2018-11-16 02:31:14

# %%
df['ymd'] = df['utc_time'].dt.date
df.head(10)
# Out:
#                        imei                                  AdID  \
# 0  04G0LT445QLQT5NTP40L5TPG  28075d03-b93c-4fb6-830e-b56521c50248
# 1  04G5NNOJ5QONQ5JTP4LG5TPQ  10e21cbe-9284-423b-8338-a38cbe23d459
# 2  04GG4TT55JTL05QTP4LJ5TPG  fac98d45-50b9-43c3-beb2-990e6348f5dd
# 3  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 4  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 5  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 6  04GLNLG45OTNQ4QTP4N4TTPG  58e88563-79fd-43eb-a3ca-df5197e56372
# 7  04GNG0GJ5LQ40TGTP4QN5TP0  b1fc5946-35bc-4f7e-98bb-baceabec78c2
# 8  04GQJQLO55GQNTQTP4O5TTPJ  995186aa-a6aa-4188-ac05-3d50b44d8084
# 9  04GQO4GQ5TQGGT4TP4NN5TPL  cb9112ea-d618-43c0-8d6f-ba8fa4e0364a
#
#              jst_time            utc_time         hour_before         ymd
# 0 2018-06-01 16:57:55 2018-06-01 07:57:55 2018-06-01 06:57:55  2018-06-01
# 1 2018-12-27 11:59:50 2018-12-27 02:59:50 2018-12-27 01:59:50  2018-12-27
# ...

# %%
df.dtypes
# Out:
# imei                   object
# AdID                   object
# jst_time       datetime64[ns]
# utc_time       datetime64[ns]
# hour_before    datetime64[ns]
# ymd                    object
# dtype: object

# %%
for i, x in df.groupby(df['ymd']):
    x.to_csv('{}/{}.csv'.format(output,i), index=False)
